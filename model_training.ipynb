# %%
# imports
import pandas as pd
import numpy as np
import torch
import xgboost as xgb

# %%
### Data
training_m = pd.read_csv("train_data_m.csv")

# %%
#data loader
train_loader_m = torch.utils.data.DataLoader(training_m, batch_size=64, shuffle=True)

# %%
model = torch.nn.Sequential() # Sequential means we can add a series of layer

model.add_module('fc1', torch.nn.Linear(28, 1)) # add a fully connected layer with 2 output units (one for each class)

# let's view the model
print(model)
# Out:
# Sequential(
#   (fc1): Linear(in_features=28, out_features=1, bias=True)
# )
